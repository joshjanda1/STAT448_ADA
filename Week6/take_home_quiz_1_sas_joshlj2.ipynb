# %% [markdown]
# ## Take-Home Quiz - SAS
#
# Grading Rubric (per question):
# 2 points if complete and correct
# 1 point if incomplete or incorrect
# 0 points if no attempt made
#
# The following questions should be completed with you by yourself, thus you are the *designated submitter* (who must submit (commit/push) the answers to the take home quiz in your repo. The deadline to submit this quiz is **9:00 am Monday March 2, 2020**. Do not change anything in this file above the line.
#
# ***
#
# **#0** Pull this ipynb file from your respective **assignments_section_sp20** repo; either **assignments_section2_sp20** or **assignments_section3_sp20**. Copy it into your personal repo to begin answering the questions, but rename the file as take_home_quiz_1_sas_Netid.ipynb with your Netid. (GitHub)
#
# ***

# %% [markdown]
# **#1** Using Markdown syntax (not SAS syntax), make a bulleted list that has your first name in italic font in one bullet and your last name in bold font in another bullet. (Markdown)

# %% [markdown]
# - *Josh*
# - **Janda**

# %% [markdown]
# **#2** Using Markdown syntax (not SAS syntax), make a numbered list that has 3 items. Number 1 should contain a hyperlink for the STAT 448 course website (not the GitHub Enterprise site). Number 2 should contain the URL of the STAT 448 course website and my email address as links. Number 3 should contain a blockquote of the STAT 448 course information which appears in the syllabus. (Markdown, Syllabus)

# %% [markdown]
# 1. [STAT 448 Course Website](http://publish.illinois.edu/kinson2/teaching/stat-448/)
# 2. http://publish.illinois.edu/kinson2/teaching/stat-448/ [kinson2@illinois.edu](mailto:kinson2@illinois.edu)
# 3. > Advanced Data Analysis (STAT 448) is a very broad analytics course that aims to cover several topics in statistics and data science and to apply these methodologies in statistical computing software including SAS and R. The topics in the course include descriptive statistics and inference, visualizations, exploratory data analysis, and modeling. The expectation is that students will become proficient data analysts who understand how to explain statistical results as well as how to craft narratives with data using SAS and R. Critical (and statistical) thinking and captivating design will be pushed as well as written and oral presentation of findings. This course aims to push students to investigate problems and employ aspects of the investigative process for data analysis with a special focus on visualizations and data exploration.

# %% [markdown]
# **#3** Using the visualization below, describe what's happening in the plot. (Data Visualization, Markdown)
# ![](https://uofi.box.com/shared/static/fa95r5o558q61llcldkctjvijwy7sy7o.jpg)

# %% [markdown]
# This is not a plot. This is some type of fabric that is zoomed in on, so there is nothing actually happening.

# %% [markdown]
# **#4** Using Markdown syntax (not SAS syntax) and the visualization below, make two separate numbered lists. The first list contains 2 items that are good about the visualization. The second list contains 2 items that you would suggest as changes in order to improve the plot. (Markdown, Visual Design Principles, Data Visualization)
# ![](https://uofi.box.com/shared/static/ggmu0rlojjzup8rf97f593ywkqyfg5c5.png)

# %% [markdown]
# Good Items:
# 1. There are legends that let the reader understand the meaning behind the different colored points in the plot.
# 2. The axis's are clearly labeled as to what they are.
#
# What I would change:
# 1. Make the plot title clearer as to what we are looking at, as well as the legend titles. What are the risk levels? Risk level of getting in a car accident? I would clearly label the visualization better.
# 2. Decrease the alpha value due to the point density. This will make the visualization easier to look at and understand by letting less point-dense areas be more transparent.

# %% [markdown]
# **#5** Import only the 1st, 10th, and 20th parts of the 2015 US Natality Data, keeping only the variables in the list below (not case sensitive). After importing, merge the 3 data sets into 1 single data set called **nat**. *You must use the options statement to prevent extaneous SAS output for this problem.* (SAS, Accessing and Importing Data, Data Wrangling)
#
#   - M_Ht_In
#   - BMI
#   - PWgt_R
#   - DWgt_R
#   - RF_PDIAB
#   - RF_GDIAB
#   - RF_PHYPE
#   - RF_GHYPE
#   - RF_EHYPE
#   - RF_PPTERM
#   - RF_CESAR
#   - ME_PRES
#   - ATTEND
#   - PAY_REC
#   - APGAR5
#   - APGAR10
#   - AB_NICU
#   - BFED
#   - priorlive
#   - priordead
#   - mrace6
#   - frace6
#   - dplural
#   - OEGest_R3
#   - SEX
#   - MAGER
#   - FAGECOMB
#   - MEDUC
#   - FEDUC
#   - PREVIS_REC
#   - previs
#   - CIG_REC
#   - WTGAIN
#   - DMETH_REC
#   - dbwt

# %%
options nosource nonotes errors=0;
filename nat1 url "https://uofi.box.com/shared/static/gb07nz7jafspk65wzxq6awlu02kypiq7.csv" termstr=crlf;
filename nat10 url "https://uofi.box.com/shared/static/xf7r94alpzaqv4wxh5liqw7rpk21wb6l.csv" termstr=crlf;
filename nat20 url "https://uofi.box.com/shared/static/eq9k4d73ansal5p8mspu3mpslmzs7x8g.csv" termstr=crlf;

proc import datafile=nat1 out=birth01(keep = M_Ht_In BMI PWgt_R DWgt_R
                                            RF_PDIAB RF_GDIAB RF_PHYPE RF_GHYPE RF_EHYPE
                                            RF_PPTERM RF_CESAR ME_PRES ATTEND 
                                            PAY_REC APGAR5 APGAR10 AB_NICU BFED priorlive
                                            priordead mrace6 frace6 dplural OEGest_R3
                                            SEX MAGER FAGECOMB MEDUC FEDUC PREVIS_REC
                                            previs CIG_REC WTGAIN DMETH_REC dbwt) replace dbms=csv; 
run;

proc import datafile=nat10 out=birth10(keep = M_Ht_In BMI PWgt_R DWgt_R
                                            RF_PDIAB RF_GDIAB RF_PHYPE RF_GHYPE RF_EHYPE
                                            RF_PPTERM RF_CESAR ME_PRES ATTEND 
                                            PAY_REC APGAR5 APGAR10 AB_NICU BFED priorlive
                                            priordead mrace6 frace6 dplural OEGest_R3
                                            SEX MAGER FAGECOMB MEDUC FEDUC PREVIS_REC
                                            previs CIG_REC WTGAIN DMETH_REC dbwt) replace dbms=csv; 
run;

proc import datafile=nat20 out=birth20(keep = M_Ht_In BMI PWgt_R DWgt_R
                                            RF_PDIAB RF_GDIAB RF_PHYPE RF_GHYPE RF_EHYPE
                                            RF_PPTERM RF_CESAR ME_PRES ATTEND 
                                            PAY_REC APGAR5 APGAR10 AB_NICU BFED priorlive
                                            priordead mrace6 frace6 dplural OEGest_R3
                                            SEX MAGER FAGECOMB MEDUC FEDUC PREVIS_REC
                                            previs CIG_REC WTGAIN DMETH_REC dbwt) replace dbms=csv; 
run;
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #ffffff; }
# body .c { color: #0000FF } /* Comment */
# body .k { color: #ff0000; font-weight: bold } /* Keyword */
# body .n { color: #008000 } /* Name */
# body .ch { color: #0000FF } /* Comment.Hashbang */
# body .cm { color: #0000FF } /* Comment.Multiline */
# body .cp { color: #0000FF } /* Comment.Preproc */
# body .cpf { color: #0000FF } /* Comment.PreprocFile */
# body .c1 { color: #0000FF } /* Comment.Single */
# body .cs { color: #0000FF } /* Comment.Special */
# ...

# %%
data nat;
    set birth01 birth10 birth20;
run;

options source notes errors=20;
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #ffffff; }
# body .c { color: #0000FF } /* Comment */
# body .k { color: #ff0000; font-weight: bold } /* Keyword */
# body .n { color: #008000 } /* Name */
# body .ch { color: #0000FF } /* Comment.Hashbang */
# body .cm { color: #0000FF } /* Comment.Multiline */
# body .cp { color: #0000FF } /* Comment.Preproc */
# body .cpf { color: #0000FF } /* Comment.PreprocFile */
# body .c1 { color: #0000FF } /* Comment.Single */
# body .cs { color: #0000FF } /* Comment.Special */
# ...

# %% [markdown]
# **#6** Using SAS, delete (from the computer's memory) the 3 data sets that were imported in **Problem 5**. With the **nat** data that was created in **Problem 5**, remove any unknown or missing values. (SAS, Accessing and Importing Data, Data Wrangling)

# %%
proc delete data=birth01;
run;
proc delete data=birth10;
run;
proc delete data=birth20;
run;

data nat;
    set nat;
    if M_Ht_In ne 99 and BMI ne 99.9 and PWgt_R ne 999 and DWgt_R ne 999
       and RF_PDIAB ne "U" and RF_GDIAB ne "U" and RF_PHYPE ne "U"
       and RF_GHYPE ne "U" and RF_EHYPE ne "U" and RF_PPTERM ne "U"
       and RF_CESAR ne "U" and ME_PRES ne 9 and ATTEND ne 9
       and PAY_REC ne 9 and APGAR5 ne 99 and APGAR10 ne 99
       and AB_NICU ne "U" and BFED ne "U" and priorlive ne 99
       and priordead ne 99 and frace6 ne 9 and OEGest_R3 ne 3
       and FAGECOMB ne 99 and MEDUC ne 9 and FEDUC ne 9 and PREVIS_REC ne 12
       and previs ne 99 and CIG_REC ne "U" and WTGAIN ne 99 and DMETH_REC ne 9
       and dbwt ne 9999;
run;
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #ffffff; }
# body .c { color: #0000FF } /* Comment */
# body .k { color: #ff0000; font-weight: bold } /* Keyword */
# body .n { color: #008000 } /* Name */
# body .ch { color: #0000FF } /* Comment.Hashbang */
# body .cm { color: #0000FF } /* Comment.Multiline */
# body .cp { color: #0000FF } /* Comment.Preproc */
# body .cpf { color: #0000FF } /* Comment.PreprocFile */
# body .c1 { color: #0000FF } /* Comment.Single */
# body .cs { color: #0000FF } /* Comment.Special */
# ...

# %% [markdown]
# **#7** Using SAS and beginning with the merged data in **Problem 6**, randomly select 30,000 observations with the PROC SURVEYSELECT and change the default seed number to be the last 4 digits of your UIN. Call this newly created data set **birthran**. (SAS, Accessing and Importing Data, Data Wrangling)

# %%
proc surveyselect data=nat method=srs n=30000 out=birthran seed=8173;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# **#8** Using SAS and beginning with the **birthran** data in **Problem 7**, do the following wrangling processes.
#
#   - name this new data set **birth**
#   - create a new variable called "riskfactorbin" which equals 1 if the mother has any of the 7 risk factors and equals 0 otherwise
#   - create a new variable called "dbwtlbs" which equals the baby's birth weight in pounds
#   - drops all risk factor variables
#   - drops previs_rec
#
# Now show the first 10 observations of the **birth** data and the following columns: oegest_r3, previs, dbwtlbs, bmi, and attend. (SAS, Accessing and Importing Data, Data Wrangling)

# %%
data birth;
    set birthran;
    if RF_PDIAB = "Y" or RF_GDIAB = "Y" or RF_PHYPE = "Y"
       or RF_GHYPE = "Y" or RF_EHYPE = "Y" or RF_PPTERM = "Y"
       or RF_CESAR = "Y" then riskfactorbin = 1;
    else riskfactorbin = 0;
    dbwtlbs = dbwt / 454;
    drop RF_PDIAB RF_GDIAB RF_PHYPE RF_GHYPE
         RF_EHYPE RF_PPTERM RF_CESAR previs_rec;
run;

proc print data=birth(obs=10);
    var oegest_r3 previs dbwtlbs bmi attend;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# **#9** Using SAS and beginning with the **birth** data in **Problem 8**, partition it to create a training data set (70% of the observations) and a testing data set (30% of the observations). These two new data sets must have been produced with randomization and with the last 4 digits of your UIN as the seed number again. Call the training set **birthtrn** and the testing set **birthtst**. (SAS, Accessing and Importing Data, Data Wrangling)

# %%
data birth1;
    set birth;
    call streaminit(8173);
    n=rand('uniform');
run;

proc sort data=birth1;
    by n;
run;
    
data birthtrn birthtst;
    set birth1 nobs=nobs;
    if _n_<=.70*nobs then output birthtrn;
    else output birthtst;
run;
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #ffffff; }
# body .c { color: #0000FF } /* Comment */
# body .k { color: #ff0000; font-weight: bold } /* Keyword */
# body .n { color: #008000 } /* Name */
# body .ch { color: #0000FF } /* Comment.Hashbang */
# body .cm { color: #0000FF } /* Comment.Multiline */
# body .cp { color: #0000FF } /* Comment.Preproc */
# body .cpf { color: #0000FF } /* Comment.PreprocFile */
# body .c1 { color: #0000FF } /* Comment.Single */
# body .cs { color: #0000FF } /* Comment.Special */
# ...

# %% [markdown]
# **#10** Using SAS and beginning with the **birthtrn** data in **Problem 9**, recreate the data visualization below. *Obviously, each student's **birthtrn** and **birthtst** will be different.* (SAS, Data Visualization, Visual Design Principles)
#
# ![](https://uofi.box.com/shared/static/u47cbvrt9b4o5rzqq977idqsbdfi096l.png)

# %%
data birthtrn_graph;
    set birthtrn;
    if OEGest_R3 = 1 then Born_Preemie = 'Yes';
    else Born_Preemie = 'No';
run;

data attrmap;
 input id $ value $ fillcolor $ linecolor $;
 datalines;
 myid Yes CX48D1CC CX48D1CC
 myid No salmon salmon
 ;
run;

proc sgplot data=birthtrn_graph dattrmap=attrmap;
    vbar SEX / group = Born_Preemie stat=freq groupdisplay=cluster attrid=myid datalabel;
    keylegend / location=inside positon=topright title="Born Premature" across=1;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# **#11** Using SAS and beginning with the **birthtst** data in **Problem 9**, recreate the data visualization below. *Obviously, each student's **birthtrn** and **birthtst** will be different.* (SAS, Data Visualization, Visual Design Principles)
#
# ![](https://uofi.box.com/shared/static/uzla1knz6an54ldmcb3uajfo0jy7lma6.png)

# %%
proc means data=birthtst noprint;
 class PREVIS;
 var WTGAIN;
 output out=prob11data mean=avgweightgain;
run;

title "Mother's Avg Weight Gain Across Number of Prenatal Visits";
proc sgplot data=prob11data noborder;
    series x=previs y=avgweightgain;
    xaxis display=(noline);
    yaxis display=(noline);
run;
title;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# **#12** Using SAS and beginning with the **birthtrn** data in **Problem 9**, determine if there are any outliers in the data. Give evidence as to which points are outliers and why they are outliers. If there are no outliers, give your reasoning for why there are no outliers in the data. (SAS, Data Descriptives, Data Visualization)

# %%
proc sgplot data=birthtrn;
    hbox mager;
run;
proc sgplot data=birthtrn;
    hbox fagecomb;
run;
proc sgplot data=birthtrn;
    hbox previs;
run;
proc sgplot data=birthtrn;
    hbox M_HT_IN;
run;
proc sgplot data=birthtrn;
    hbox BMI;
run;
proc sgplot data=birthtrn;
    hbox PWGT_R;
run;
proc sgplot data=birthtrn;
    hbox DWGT_R;
run;
proc sgplot data=birthtrn;
    hbox WTGAIN;
run;
proc sgplot data=birthtrn;
    hbox dbwtlbs;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# Looking at the box plots above, there are definitely outliers in the data. Using the box plot role, which is the $1.5*IQR$ rule, outliers can be seen in each individual continuous variable. These observations that are seen outside the $1.5*IQR$ range in each of the box plot are outliers because these observations are either $ < Q1 - 1.5 * IQR$ or $ > Q3 + 1.5*IQR$, meaning that they are either less than the first quantile minus 1.5 times the interquartile range ($Q3-Q1$) or they are greater than the third quantile plus 1.5 times the interquartile range. Each point outside of this range in each variable is considered an outlier.

# %% [markdown]
# **#13** Using SAS and beginning with the **birthtst** data in **Problem 9**, determine if there are any outliers in the data. Give evidence as to which points are outliers and why they are outliers. If there are no outliers, give your reasoning for why there are no outliers in the data. (SAS, Data Descriptives, Data Visualization)

# %%
proc sgplot data=birthtst;
    hbox mager;
run;
proc sgplot data=birthtst;
    hbox fagecomb;
run;
proc sgplot data=birthtst;
    hbox previs;
run;
proc sgplot data=birthtst;
    hbox M_HT_IN;
run;
proc sgplot data=birthtst;
    hbox BMI;
run;
proc sgplot data=birthtst;
    hbox PWGT_R;
run;
proc sgplot data=birthtst;
    hbox DWGT_R;
run;
proc sgplot data=birthtst;
    hbox WTGAIN;
run;
proc sgplot data=birthtst;
    hbox dbwtlbs;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# Similar to the plots above using the training data, we are able to see that there are outliers in each continuous variable in the test dataset. An observation is considered an outlier when it is outside the the $1.5*IQR$ data. It is expected that the test dataset would have outliers if the training set does, since both datasets come from random sampling of the full dataset.

# %% [markdown]
# **#14** Using SAS and beginning with the **birth** data in **Problem 8**, conduct a principal components analysis (PCA) on the variables that are not categorical and not binary. Explain how many components to keep and give reasoning for that chosen number. *You must use ods select to limit the amount of SAS output.* (SAS, Principal Components Analysis, Data Visualization)

# %%
proc princomp data=birth out=pcbirth outstat=pcstatbirth;
    var APGAR10 APGAR5 PREVIS wtgain pwgt_r dwgt_r dbwtlbs dbwt bmi M_HT_IN mager fagecomb;
    ods select Eigenvalues ScreePlot ;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# Looking at the plot above, I would select a total of 7 principal components to keep. This is because at 7 prinicipal components, using the explained variance plot, we can see that at 7 principal components we have retained almost all variance in the data while being able to reduce the number of variables needed. Also, using the Scree Plot we can see that Eigenvalue dips a good amount between the 7th and 8th principal component which makes the 8th principal component not worth keeping.
#
# Looking at the Eigenvalues of the correlation matrix, it confirms my reasoning of why to keep up to the 7th principal component. It's Eigenvalue is still near one, which is the average, and is the last eigenvalue to contain a sizeable amount of proportion of variance in the data.

# %% [markdown]
# **#15** Using SAS and the PCA results in **Problem 14**, give an interpretation of the first 3 components. This interpretation should be descriptive and should not include numeric descriptions of the values of the eigenvectors. Additionally, you must show visualizations of these first 3 components as evidence to go along with your interpretation. (SAS, Principal Components Analysis, Data Visualization)

# %%
proc princomp data=birth out=pcbirth outstat=pcstatbirth plots(ncomp=3)=(pattern);
    var APGAR10 APGAR5 PREVIS wtgain pwgt_r dwgt_r dbwtlbs dbwt bmi M_HT_IN mager fagecomb;
    ods select patternplot Eigenvectors;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# The interpretation for component 1, we can see that all eigenvectors are near zero so this component can be interepreted as an overall behavior of all variables.
#
# For the second component, all eigenvectors are not near zero and they are also not in the same direction. This component can be interepreted as a grouping behavior, possibly grouping variables into groups depending on correlations. We see that dbwt/dbwtlbs have the same eigenvector since they have a correlation of 1 and are grouped together. Another group of variables that are similar are WTGAIN, DWGT_R, PWGT_R, BMI. All of these variables are related to mother's weight and are correlated.
#
# For the third component, all eigenvectors are not near zero and also are not in the same direction. Similar to the second component, this variable can be interpreted as a grouping behavior. This component seems to continue to group together variables that are correlated with one another. This component seems to group together completely variables related to childbirth and variables not related as mother and father age is far away from the rest of the variables.
#
# Using the graphs above my interpretation is supported as the first plot being more of an overall behavioral plot, and the second and third plots displaying more signs of variable groupings.

# %% [markdown]
# **#16** Using SAS, use linear regression to predict a baby's birth weight in pounds (dbwtlbs). You must compare 2 sets of predictors to seek a better prediction. This problem requires the use of only **birthtrn** (building the model and testing how well it performs).
#
# Describe the results of the better model and how good it is at predicting a baby's birth weight. (SAS, GLM - Linear Regression, Data Visualization, Markdown)

# %%
proc reg data=birthtrn;
    model dbwtlbs = pwgt_r dwgt_r wtgain apgar10 previs m_ht_in fagecomb mager
                    mrace6 meduc frace6 feduc priorlive priordead me_pres
                    dmeth_rec attend pay_rec apgar5 dplural riskfactorbin oegest_r3
          / selection=stepwise sle=0.5 sls=0.05;
    ods select selectionsummary;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# Looking at the output above, we compared more than 2 sets of predictors for building a better predicting linear regression model for a baby's birth weight in pounds. This was done through the use of stepwise selection, where variables are added and removed from the model based on whether they improve the models predicting power. Our final model contains all variables that were listed in the regression call, but removes the **APGAR10** variable as it showed no increase in the models prediction power. Our final model has an $R^2$ of .3674, which is pretty good as our model can explain about 36.74% of the variance in the data.

# %% [markdown]
# **#17** Using SAS, use poisson regression to predict a baby's birth weight in grams (dbwt). You must compare 2 sets of predictors to seek a better prediction. This problem requires the use of only **birthtrn** (building the model and testing how well it performs).
#
# Describe the results of the better model and how good it is at predicting a baby's birth weight. (SAS, GLM - Poisson Regression, Data Visualization, Markdown)

# %%
proc genmod data=birthtrn;
 class MRACE6 MEDUC FRACE6 FEDUC PRIORLIVE PRIORDEAD ME_PRES DMETH_REC ATTEND PAY_REC DPLURAL OEGEST_R3 riskfactorbin/ param=ref ref=first;
 model dbwt = pwgt_r dwgt_r wtgain apgar10 previs m_ht_in fagecomb mager
                    mrace6 meduc frace6 feduc priorlive priordead me_pres
                    dmeth_rec attend pay_rec apgar5 dplural riskfactorbin oegest_r3 / dist=poisson link=log type1 type3;
 ods select modelfit modelanova;
run;

proc genmod data=birthtrn;
 class MRACE6 MEDUC FRACE6 FEDUC PRIORLIVE PRIORDEAD ME_PRES DMETH_REC ATTEND PAY_REC DPLURAL OEGEST_R3 riskfactorbin/ param=ref ref=first;
 model dbwt = pwgt_r wtgain apgar10 previs m_ht_in fagecomb mager
                    mrace6 meduc frace6 feduc priorlive priordead me_pres
                    dmeth_rec attend pay_rec apgar5 dplural riskfactorbin oegest_r3 / dist=poisson link=log type1 type3;
 ods select modelfit modelanova;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# Looking at the Type 3 Analysis output above, all variables are significant except the DWGT_R variable. So, I removed this predictor from the model and reran to see if our predictions improved. This removal of the variable resulted in a slightly better model when comparing AIC, AICC, and BIC scores. Overall, the model with the removed predictor gave me a better performing model.

# %% [markdown]
# **#18** Using SAS, use logistic regression to predict whether a baby is born prematurely or not (OEGest_R3). You must compare 2 sets of predictors to seek a better prediction. This problem requires the use of both **birthtrn** (building the model) and **birthtst** (testing how well it performs).
#
# Describe the results of the better model and how good it is at predicting if baby is born prematurely. (SAS, GLM - Logistic Regression, Data Visualization, Markdown)

# %% [markdown]
# My prior belief for this model is that anything related to the father should only have a very small effect, if any, on whether or not the baby is born prematurely or not. So, I will create two models. The first model will contain father related variables, and the second will not. These models will be scored on the test data.

# %%
proc logistic data=birthtrn outmodel=logistic_model1;
 class MRACE6 MEDUC FRACE6 FEDUC PRIORLIVE PRIORDEAD ME_PRES DMETH_REC ATTEND PAY_REC DPLURAL riskfactorbin / param=ref ref=first;
 model OEGEST_R3(event="1") = pwgt_r dwgt_r wtgain apgar10 previs m_ht_in fagecomb mager
                    mrace6 meduc frace6 feduc priorlive priordead me_pres
                    dmeth_rec attend pay_rec apgar5 dplural riskfactorbin;
 score data=birthtst out=preds1;
 ods select rsquare;
run;
proc logistic data=birthtrn outmodel=logistic_model2;
 class MRACE6 MEDUC PRIORLIVE PRIORDEAD ME_PRES DMETH_REC ATTEND PAY_REC DPLURAL riskfactorbin / param=ref ref=first;
 model OEGEST_R3(event="1") = pwgt_r dwgt_r wtgain apgar10 previs m_ht_in mager
                    mrace6 meduc  priorlive priordead me_pres
                    dmeth_rec attend pay_rec apgar5 dplural riskfactorbin;
 score data=birthtst out=preds2;
 ods select rsquare;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
data preds1_class;
    set preds1;
    if p_1 >= 0.5 then pred = 1;
    else pred = 2;
    keep pred;
run;
data preds2_class;
    set preds2;
    if p_1 >= 0.5 then pred = 1;
    else pred = 2;
    keep pred;
run;

proc sort data=birthtst out=birthtst_sorted(keep=OEGest_R3);
    by OEGest_R3;
run;
proc sort data=preds1_class;
    by pred;
run;
proc sort data=preds2_class;
    by pred;
run;

data tst_preds1;
    merge birthtst_sorted preds1_class;
    match = 0;
    if OEGest_R3 = pred then match = 1;
run;
data tst_preds2;
    merge birthtst_sorted preds2_class;
    match = 0;
    if OEGest_R3 = pred then match = 1;
run;
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #ffffff; }
# body .c { color: #0000FF } /* Comment */
# body .k { color: #ff0000; font-weight: bold } /* Keyword */
# body .n { color: #008000 } /* Name */
# body .ch { color: #0000FF } /* Comment.Hashbang */
# body .cm { color: #0000FF } /* Comment.Multiline */
# body .cp { color: #0000FF } /* Comment.Preproc */
# body .cpf { color: #0000FF } /* Comment.PreprocFile */
# body .c1 { color: #0000FF } /* Comment.Single */
# body .cs { color: #0000FF } /* Comment.Special */
# ...

# %%
title 'Father Variables Included';
proc means data=tst_preds1 mean;
    var match;
run;
title 'Father Variables not Included';
proc means data=tst_preds2 mean;
    var match;
run;
title;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# Looking at the output above of the mean accuracy rate on the test dataset, we get a better accuracy score from the model where father variables are not included. For included father variables, our accuracy rate is ~.9589 whereas when not including father variables our accuracy rate is ~.9592. This supports my hypothesis that father related information does not play a large role on whether or not a baby is born prematurely.

# %% [markdown]
# **#19** Using SAS, use linear discriminant analysis to predict whether a baby is born prematurely or not (OEGest_R3). You must compare 2 sets of predictors to seek a better prediction. This problem requires the use of both **birthtrn** (building the model) and **birthtst** (testing how well it performs).
#
# Describe the results of the better model and how good it is at predicting if baby is born prematurely. (SAS, Discriminant Analysis, Data Visualization, Markdown)

# %% [markdown]
# Once again, as above, I will be testing again if father variables are relevant to whether or not a baby is born prematurely. I will be using LDA for this.

# %%
title 'Father Variables Included';
proc discrim data=birthtrn outstat=trainingsetrez1 pool=test manova testdata=birthtst testout=testingsetrez1;
 class OEGest_R3;
 var pwgt_r dwgt_r wtgain apgar10 previs m_ht_in fagecomb mager
                    mrace6 meduc frace6 feduc priorlive priordead me_pres
                    dmeth_rec attend pay_rec apgar5 dplural riskfactorbin;
 priors prop;
 ods select errortestclass classifiedtestclass;
run;
title 'Father Variables not Included';
proc discrim data=birthtrn outstat=trainingsetrez1 pool=test manova testdata=birthtst testout=testingsetrez1;
 class OEGest_R3;
 var pwgt_r dwgt_r wtgain apgar10 previs m_ht_in mager
                    mrace6 meduc  priorlive priordead me_pres
                    dmeth_rec attend pay_rec apgar5 dplural riskfactorbin;
 priors prop;
 ods select errortestclass classifiedtestclass;
run;
title;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# Looking at the output above for the LDA models of both father variables included and not, we see similar results as the logistic regression. We have a slightly lower misclassification rate for the model that does not include father variables (.0996 vs .1002). This confirms my belief once again that including father related variables hurts our model for predicting whether a baby is born prematurely or not. It should also be noted that for both models the misclassification rate for predicting that a baby is born prematurely is .6173 which is very high.
#
# Overall, our best model has a low misclassification rate on the test data set which is great. However, I would not use this model for it's purpose of classifying if a baby will be born prematurely due to it's high error rate on those that are born prematurely.

# %% [markdown]
# **#20** Using SAS, use kNN classification to predict whether a baby is born prematurely or not (OEGest_R3). You must compare 2 sets of predictors to seek a better prediction. This problem requires the use of both **birthtrn** (building the model) and **birthtst** (testing how well it performs).
#
# Describe the results of the better model and how good it is at predicting if baby is born prematurely. (SAS, kNN Classification, Data Visualization, Markdown)

# %% [markdown]
# Once again, as above, I will be testing again if father variables are relevant to whether or not a baby is born prematurely. I will be using KNN for this.

# %%
title 'Father Variables Included';
proc discrim data=birthtrn method=npar k=3 outstat=trainingsetrez1 testdata=birthtst testout=testingsetrez1;
 class OEGest_R3;
 var pwgt_r dwgt_r wtgain apgar10 previs m_ht_in fagecomb mager
                    mrace6 meduc frace6 feduc priorlive priordead me_pres
                    dmeth_rec attend pay_rec apgar5 dplural riskfactorbin;
 priors prop;
 ods select errortestclass classifiedtestclass;
run;
title 'Father Variables not Included';
proc discrim data=birthtrn method=npar k=3 outstat=trainingsetrez1 testdata=birthtst testout=testingsetrez1;
 class OEGest_R3;
 var pwgt_r dwgt_r wtgain apgar10 previs m_ht_in mager
                    mrace6 meduc  priorlive priordead me_pres
                    dmeth_rec attend pay_rec apgar5 dplural riskfactorbin;
 priors prop;
 ods select errortestclass classifiedtestclass;
run;
title;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# Looking at the output above for the results of the models on the test dataset, we see the same issues as LDA. I have overall low misclassification rates, but extremely high misclassification rates when classifying that a baby will be born prematurely. It should also be noted that this time around, including father variables resulted in a lower misclassification rate on the test set compared to not including them.
#
# Overall, this model should not be used for predicting whether or not a baby will be born prematurely. With such high misclassification rates, one would be better off guessing rather than using this model.

# %% [markdown]
# **#00** The **designated submitter** should commit and push the file to their repo with the commit message "All Done".
